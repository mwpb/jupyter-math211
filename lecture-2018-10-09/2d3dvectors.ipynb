# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from pythonUtils.plottingUtils import plot2DSystem, printM, plotColumns, plotVectors, plot3dVectors
import numpy as np

# %config InlineBackend.figure_format = 'png'
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# %pylab inline
pylab.rcParams['figure.figsize'] = (8,8)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib

# %%
A = [
    [1, 0, "blue"],
    [0, 1, "red"],
    [3,2, "black"]
]
plotVectors(A)

# %%
A = [
    [1,0,0, "blue"],
    [0,1,0, "red"],
    [0,0,1, "green"],
    [2,1,1, "black"]
]
plot3dVectors(A)

# %%
A = [
    [0,0,2,1, "blue"],
    [0,0,1,4, "red"],
    [1, 4, 3, 5, "lightblue"],
    [2, 1, 3, 5, "pink"],
    [0,0,3,5, "black"]
]
plotVectors(A)

# %%
A = [
    [0, 0,2, 1, "blue"],
    [0, 0,4, 2, "blue", False]
]
B = [
    [0, 0,4, 2, "blue"],
    [0, 0,2,1, "blue", False]
]
plotVectors(A)
plotVectors(B)

# %%
A = [
    [0,0,-1,3, "blue"],
    [0,0,2,1, "red"],
    [-1,3,2,1, "lightgrey"],
    [-1,3,0.5,2, "black"],
]
plotVectors(A)

# %%
A = [
    [0,0,-1,3, "blue"],
    [0,0,2,1, "red"],
    [-1,3,2,1, "limegreen"]
]
plotVectors(A)
